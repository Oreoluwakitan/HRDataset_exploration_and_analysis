# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import streamlit as st

# %%
df = pd.read_csv('HRDataset_v14 org excel - Copy.csv')

# %%
to_cast = ['DOB', 'DateofHire', 'DateofTermination']
for cols in to_cast:
    df[cols] = df[cols].astype('datetime64[ns]')

# %%
df['TermReason']= df['TermReason'].str.replace('N/A-', '')

# %%
df['Employee_Name']= df['Employee_Name'].str.replace(',', '')

# %%
df = df.drop(columns = ['MarriedID', 'GenderID', 'FromDiversityJobFairID', 'Termd', 'LastPerformanceReview_Date'], axis = 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee_Name         311 non-null    object
#  1   EmpID                 311 non-null    int64
#  2   MaritalStatusID       311 non-null    int64
#  3   EmpStatusID           311 non-null    int64
#  4   DeptID                311 non-null    int64
#  5   PerfScoreID           311 non-null    int64
#  6   Salary                311 non-null    int64
#  7   PositionID            311 non-null    int64
#  8   Position              311 non-null    object
#  9   State                 311 non-null    object
#  10  Zip                   311 non-null    int64
#  11  DOB                   311 non-null    datetime64[ns]
#  12  Sex                   311 non-null    object
#  13  MaritalDesc           311 non-null    object
#  14  CitizenDesc           311 non-null    object
# ...

# %%
df.head()
# Out:
#          Employee_Name  EmpID  MaritalStatusID  EmpStatusID  DeptID  \
# 0            Brown Mia  10238                1            1       2
# 1  LaRotonda William    10038                2            1       2
# 2      Steans Tyrone    10147                0            1       2
# 3           Singh Nan   10039                0            1       2
# 4   LeBlanc Brandon  R  10134                1            1       2
#
#    PerfScoreID  Salary  PositionID                  Position State  ...  \
# 0            2   63000           1              Accountant I    MA  ...
# 1            2   64520           1              Accountant I    MA  ...
# 2            2   63003           1              Accountant I    MA  ...
# 3            2   51920           2  Administrative Assistant    MA  ...
# 4            2   93046          24   Shared Services Manager    MA  ...
#
#       Department         ManagerName ManagerID   RecruitmentSource  \
# ...

# %%
header = st.container()

with header:
    st.title('This is a test')
